# %%
import pandas as pd

# %%
dataframe = pd.read_csv("android_bids_us.csv")

# %%
dataframe
# Out:
#                                         bidid       utc_time  \
# 0        87b0108c-6e9f-4783-8b80-8dd5aa3529a8  1536444331894
# 1        9284441f-a6ea-4698-9017-86436b92d416  1536444363932
# 2        7e4779c2-f757-4324-8c2a-138b558b5a54  1536444386908
# 3        b64ea208-38ca-42ac-895e-0842d7352cc3  1536444405023
# 4        fd0c07cb-31f6-408c-9315-1cb652e76abc  1536444443458
# ...                                       ...            ...
# 3148823  a38d5eba-ad93-430e-8323-dd8ea0d713a2  1541472458853
# 3148824  f4cb0a53-c02c-43a2-9d44-fcd79f18127e  1541472485093
# 3148825  6c9a06ab-29ac-445d-b4e0-e7ebe66ce2b1  1541472516760
# 3148826  df975817-8218-4709-a9c0-e1d56c4a63b4  1541472552347
# 3148827  971a5f81-96e0-4694-be22-5809e90de06d  1541472553004
#
#                                                     app_id user_state  \
# 0                                   com.OppanaGames.CarSim         TX
# 1                          com.mobilityware.CrownSolitaire         TX
# 2                            com.kuttigames.tenkyurollball         LA
# 3        com.trendactionfree.call_of_sniper_duty_frontl...         TN
# 4                         com.landslab.my3rdgrademathgames         NC
# ...                                                    ...        ...
# 3148823                                  com.altitude.rrsv         TX
# 3148824                                com.slots.realvegas         GA
# 3148825                      br.com.tapps.penguinevolution         MO
# 3148826               air.com.FDGEntertainment.Lonewolf.gp         WI
# 3148827                        com.shoot.strike.gun.fire.d         CA
#
#                user_isp device_maker            device_model device_osv  \
# 0         AT&T Wireless          NaN                     NaN        7.0
# 1          T-Mobile USA          NaN                     NaN        7.0
# 2         AT&T Wireless          NaN                     NaN      7.1.1
# 3         Comcast Cable          NaN                     NaN      6.0.1
# 4          AT&T U-verse          NaN                     NaN      7.1.1
# ...                 ...          ...                     ...        ...
# 3148823    T-Mobile USA      Samsung               SM-J327T1        7.0
# 3148824  Mediacom Cable          NaN                     NaN      8.1.0
# 3148825      Sprint PCS           LG                   SP200      7.1.2
# 3148826        Spectrum     Motorola  Moto G Plus (5th Gen.)        7.0
# 3148827   Comcast Cable           LG                   MP260        7.0
#
#          device_height  device_width marketplace  click
# 0                  720          1280  chartboost      0
# 1                 1280           720  chartboost      0
# 2                  720          1280  chartboost      0
# 3                  720          1280  chartboost      0
# 4                 1024           768  chartboost      0
# ...                ...           ...         ...    ...
# 3148823            720          1280  chartboost      0
# 3148824           1920          1080  chartboost      0
# 3148825           1280           720  chartboost      0
# 3148826           1080          1920  chartboost      0
# 3148827            720          1280  chartboost      0
#
# [3148828 rows x 12 columns]

# %%
print(dataframe.isnull().sum())
# Out:
# bidid                 0
# utc_time              0
# app_id                0
# user_state            0
# user_isp             39
# device_maker     964004
# device_model     963858
# device_osv            0
# device_height         0
# device_width          0
# marketplace           0
# click                 0
# dtype: int64

# %%
dataframe.dropna(inplace = True)

# %%
c_bidid = 'bidid'
c_utc_time = 'utc_time'
c_app_id = 'app_id'
c_user_state = 'user_state'
c_user_isp = 'user_isp'
c_device_maker = 'device_maker'
c_device_model = 'device_model'
c_device_osv = 'device_osv'
c_device_height = 'device_height'
c_device_width = 'device_width'
c_marketplace = 'marketplace'
c_click = 'click'

# %%
train_features = [c_utc_time, c_app_id, c_user_state, c_user_isp, c_device_maker,
                  c_device_model, c_device_osv, c_device_height, c_device_width]
target_feature = c_click

# %%
print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2184775 entries, 46 to 3148827
# Data columns (total 12 columns):
# bidid            object
# utc_time         int64
# app_id           object
# user_state       int64
# user_isp         int64
# device_maker     int64
# device_model     int64
# device_osv       int64
# device_height    int64
# device_width     int64
# marketplace      int64
# click            int64
# dtypes: int64(10), object(2)
# memory usage: 216.7+ MB
# None

# %%
from sklearn.preprocessing import LabelEncoder

categorical_attrs = dataframe.select_dtypes(include='object').columns.difference([c_bidid, c_app_id])

for label in categorical_attrs:
    encoder = LabelEncoder()
    dataframe[label] = encoder.fit_transform(dataframe[label])

# %%
dataframe
# Out:
#                                         bidid       utc_time  \
# 46       c11b24e7-8471-41f5-82af-24be5d1a3c1f  1537855513297
# 47       ca89d32e-85d8-4cd8-a681-0a5902d0cf55  1537855549353
# 48       5f6268a1-58d8-4a3d-b06b-4293484ee6c8  1537855629973
# 49       d89c308a-a29c-4d8c-a61b-4f2426877f51  1537855674264
# 50       55ad5fc9-467e-4bcf-84d1-9deaf70158b1  1537855686541
# ...                                       ...            ...
# 3148822  7a4a5d66-ff46-42b0-9113-8b12e86a1c4d  1541472443393
# 3148823  a38d5eba-ad93-430e-8323-dd8ea0d713a2  1541472458853
# 3148825  6c9a06ab-29ac-445d-b4e0-e7ebe66ce2b1  1541472516760
# 3148826  df975817-8218-4709-a9c0-e1d56c4a63b4  1541472552347
# 3148827  971a5f81-96e0-4694-be22-5809e90de06d  1541472553004
#
#                                        app_id  user_state  user_isp  \
# 46        com.critical.strike.shoot.fire.fssc           4        35
# 47                     com.cardgame.solitaire           1        35
# 48                       com.xiart.fb.towersx           4       821
# 49                   com.thumbspire.weedfirm2          27      1967
# 50           com.zentertain.classicvegasslots          10      1889
# ...                                       ...         ...       ...
# 3148822  com.qre.Coast.Lifeguard.Beach.Rescue          43      1889
# 3148823                     com.altitude.rrsv          43      1967
# 3148825         br.com.tapps.penguinevolution          24      1889
# 3148826  air.com.FDGEntertainment.Lonewolf.gp          48      1873
# 3148827           com.shoot.strike.gun.fire.d           4       471
#
#          device_maker  device_model  device_osv  device_height  device_width  \
# 46                181          1504           3           1080          1920
# 47                181          1589           3           1280           720
# 48                181          1561           9           1080          1920
# 49                113           996           3           1280           720
# 50                113           915           3            720          1280
# ...               ...           ...         ...            ...           ...
# 3148822           181          1570           9            720          1280
# 3148823           181          1634           3            720          1280
# 3148825           113          1842           7           1280           720
# 3148826           130          1058           3           1080          1920
# 3148827           113           994           3            720          1280
#
#          marketplace  click
# 46                 0      0
# 47                 0      0
# 48                 0      1
# 49                 0      0
# 50                 0      0
# ...              ...    ...
# 3148822            0      0
# 3148823            0      0
# 3148825            0      0
# 3148826            0      0
# 3148827            0      0
#
# [2184775 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

test_data_fraction = 0.33

validation_fraction_of_train = 0.20

def split_train_test_validation(df):
    df_train, df_test = train_test_split(df, test_size = test_data_fraction,random_state=1)
    df_aux = df_train.copy()
    df_train, df_validation = train_test_split(df_aux, test_size = validation_fraction_of_train,random_state=1)
    return df_train, df_test.copy(), df_validation

# %%
df_train, df_test, df_validation = split_train_test_validation(dataframe)

X_train = df_train[train_features]
y_train = df_train[target_feature]

X_test = df_test[train_features]
y_test = df_test[target_feature]

X_validation = df_validation[train_features]
y_validation = df_validation[target_feature]
